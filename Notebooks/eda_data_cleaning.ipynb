# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Tiene que tener instalado kaggle -->pip install kaggle

# %%
# !kaggle datasets download -d mlg-ulb/creditcardfraud -p "D:\DataSets\CreditCardFraud"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
# License(s): DbCL-1.0
# ...
#   0%|          | 0.00/66.0M [00:00<?, ?B/s]
#   2%|▏         | 1.00M/66.0M [00:01<01:11, 957kB/s]
#   3%|▎         | 2.00M/66.0M [00:01<00:56, 1.19MB/s]
#   5%|▍         | 3.00M/66.0M [00:02<00:49, 1.33MB/s]
#   6%|▌         | 4.00M/66.0M [00:03<00:46, 1.40MB/s]
#   8%|▊         | 5.00M/66.0M [00:04<00:48, 1.32MB/s]
#   9%|▉         | 6.00M/66.0M [00:04<00:45, 1.39MB/s]
#  11%|█         | 7.00M/66.0M [00:05<00:41, 1.49MB/s]
#  12%|█▏        | 8.00M/66.0M [00:06<00:44, 1.35MB/s]
#  14%|█▎        | 9.00M/66.0M [00:07<00:43, 1.36MB/s]
#  15%|█▌        | 10.0M/66.0M [00:07<00:44, 1.30MB/s]
#  17%|█▋        | 11.0M/66.0M [00:08<00:44, 1.29MB/s]
#  18%|█▊        | 12.0M/66.0M [00:09<00:49, 1.14MB/s]
#  20%|█▉        | 13.0M/66.0M [00:10<00:46, 1.20MB/s]
#  21%|██        | 14.0M/66.0M [00:12<01:03, 864kB/s]
#  23%|██▎       | 15.0M/66.0M [00:15<01:19, 673kB/s]
# ...

# %% [markdown]
# #Vamos a descomprimir el archivo .zip, lo vamos a descompirmir con python

# %%
import zipfile

# %%
#Ruta del archivo zip
zip_file_path = "D:/DataSets/CreditCardFraud/creditcardfraud.zip"

#Carpeta de destino
destination_path = "D:/DataSets/CreditCardFraud"

#Extraer el archivo
with zipfile.ZipFile(zip_file_path, "r") as zip_ref:
    zip_ref.extractall(destination_path)

print("Archivo descomprimido correctamente.")
# Out:
# Archivo descomprimido correctamente.

# %%
import os
raw_path = "D:/DataSets/CreditCardFraud"

csv_path = os.path.join(raw_path, "creditcard.csv")

#Verificar si el archivo existe antes de cargarlo
if os.path.exists(csv_path):
    #Cargar el archivo CSV en un dataframe
    df = pd.read_csv(csv_path)
    print("Dataframe cargado con éxito:")
    print(df.head())  # Mostrar las primeras filas del Dataframe
else:
    print(f"El archivo {csv_path} no fue encontrado.")
# Out:
# Dataframe cargado con éxito:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...
